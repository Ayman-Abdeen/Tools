# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayman-Abdeen/Tools/blob/main/LTE_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import os
import glob
import warnings
warnings.simplefilter("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
orig_dir = os.getcwd()

# %%
orig_dir
# Out:
# '/content'

# %%
ZTE = pd.read_csv('/content/drive/MyDrive/lte/History Performance_4G_DT_AlBassiouny_20230131163429.csv', skiprows=6,usecols=[1, 9, 11, 13], names=['dateid', 'cellid', 'siteid',  'Down Time - M'], parse_dates=['dateid'])
ZTE
# Out:
#            dateid                   cellid    siteid  Down Time - M
# 0      2023-01-01  LCAI1235_12352_N_Z_D3-2  LCAI1235              0
# 1      2023-01-01  LCAI1235_12354_N_Z_D3-4  LCAI1235              0
# 2      2023-01-01  LCAI1235_12353_N_Z_D3-3  LCAI1235              0
# 3      2023-01-01  LCAI1235_12351_N_Z_D3-1  LCAI1235              0
# 4      2023-01-01  LCAI1639_16392_N_Z_D3-2  LCAI1639            900
# ...           ...                      ...       ...            ...
# 112625 2023-01-31  LDEL4296_42961_N_Z_D3-1  LDEL4296              0
# 112626 2023-01-31  LDEL1586_15862_N_Z_D3-2  LDEL1586              0
# 112627 2023-01-31  LDEL1586_15864_N_Z_D3-4  LDEL1586              0
# 112628 2023-01-31  LDEL1586_15863_N_Z_D3-3  LDEL1586              0
# 112629 2023-01-31  LDEL1586_15861_N_Z_D3-1  LDEL1586              0
#
# [112630 rows x 4 columns]

# %%
HUAWEI = pd.read_excel('/content/drive/MyDrive/lte/4G_HUAWEI_Update.xlsx',usecols=[0, 1, 2, 3], names=['dateid', 'siteid', 'cellid', 'Down Time - M'], parse_dates=['dateid'])
HUAWEI
# Out:
#            dateid     siteid                   cellid  Down Time - M
# 0      2023-01-01  64TSite e  64TSite0eNodeB0ID=26880              0
# 1      2023-01-02  64TSite e  64TSite0eNodeB0ID=26880              0
# 2      2023-01-03  64TSite e  64TSite0eNodeB0ID=26880              0
# 3      2023-01-04  64TSite e  64TSite0eNodeB0ID=26880              0
# 4      2023-01-09  64TSite e  64TSite0eNodeB0ID=26880              0
# ...           ...        ...                      ...            ...
# 364361 2023-01-31   MassiveM                      NaN              0
# 364362 2023-01-31   MassiveM                      NaN              0
# 364363 2023-01-31   MassiveM                      NaN              0
# 364364 2023-01-31   MassiveM                      NaN              0
# 364365 2023-01-31   MassiveM                      NaN              0
#
# [364366 rows x 4 columns]

# %%
Ericsson = pd.read_excel('/content/drive/MyDrive/lte/4G_Ericsson_update.xlsx',usecols=[1, 2, 3, 4], names=['dateid', 'siteid', 'cellid', 'Down Time - M'], parse_dates=['dateid'])
Ericsson
# Out:
#            dateid    siteid                   cellid  Down Time - M
# 0      2023-01-31  MCAI1457  LCAI1457_14572_R_E_D6-2        86400.0
# 1      2023-01-31  LCAI0256  LCAI0256_02567_I_E_G1-3        86400.0
# 2      2023-01-31  LCAI2239  LCAI2239_22398_N_E_G1-4        86400.0
# 3      2023-01-31  LCAI4177  LCAI4177_41770_N_E_D8-5        86400.0
# 4      2023-01-31  LCAI4177  LCAI4177_41771_N_E_D8-1        86400.0
# ...           ...       ...                      ...            ...
# 599149 2023-01-01  MCAI6072  LCAI6072_60724_N_E_D3-4            NaN
# 599150 2023-01-01  MCAI6072  LCAI6072_60725_N_E_G1-1            NaN
# 599151 2023-01-01  MCAI6072  LCAI6072_60726_N_E_G1-2            NaN
# 599152 2023-01-01  MCAI6072  LCAI6072_60727_N_E_G1-3            NaN
# 599153 2023-01-01  MCAI6072  LCAI6072_60728_N_E_G1-4            NaN
#
# [599154 rows x 4 columns]

# %%
#all_data=myDataFrame
#all_data['Date'] = pd.to_datetime(all_data['dateid'], errors='coerce')
#count = all_data.groupby(all_data['Date'].dt.date).size()
#count

# %%
#list dataframe you want to append
frame = [ZTE, HUAWEI, Ericsson]

#new dataframe to store append result
myDataFrame = pd.DataFrame()

for df in frame:
    myDataFrame = myDataFrame.append(df)

# %%
myDataFrame
# Out:
#            dateid                   cellid    siteid  Down Time - M
# 0      2023-01-01  LCAI1235_12352_N_Z_D3-2  LCAI1235            0.0
# 1      2023-01-01  LCAI1235_12354_N_Z_D3-4  LCAI1235            0.0
# 2      2023-01-01  LCAI1235_12353_N_Z_D3-3  LCAI1235            0.0
# 3      2023-01-01  LCAI1235_12351_N_Z_D3-1  LCAI1235            0.0
# 4      2023-01-01  LCAI1639_16392_N_Z_D3-2  LCAI1639          900.0
# ...           ...                      ...       ...            ...
# 599149 2023-01-01  LCAI6072_60724_N_E_D3-4  MCAI6072            NaN
# 599150 2023-01-01  LCAI6072_60725_N_E_G1-1  MCAI6072            NaN
# 599151 2023-01-01  LCAI6072_60726_N_E_G1-2  MCAI6072            NaN
# 599152 2023-01-01  LCAI6072_60727_N_E_G1-3  MCAI6072            NaN
# 599153 2023-01-01  LCAI6072_60728_N_E_G1-4  MCAI6072            NaN
#
# [1076150 rows x 4 columns]

# %%
len(myDataFrame)
# Out:
# 1076150

# %%
len(ZTE)+len(HUAWEI)+len(Ericsson)
# Out:
# 1076150

# %%
# !unzip /content/drive/MyDrive/lte/Newfolder.zip -d folder
# Out:
# Archive:  /content/drive/MyDrive/lte/Newfolder.zip
#    creating: folder/New1/
#   inflating: folder/New1/LTE  referance data - Copy (1).csv
#   inflating: folder/New1/LTE  referance data - Copy (10).csv
#   inflating: folder/New1/LTE  referance data - Copy (11).csv
#   inflating: folder/New1/LTE  referance data - Copy (12).csv
#   inflating: folder/New1/LTE  referance data - Copy (13).csv
#   inflating: folder/New1/LTE  referance data - Copy (14).csv
#   inflating: folder/New1/LTE  referance data - Copy (15).csv
#   inflating: folder/New1/LTE  referance data - Copy (16).csv
#   inflating: folder/New1/LTE  referance data - Copy (2).csv
#   inflating: folder/New1/LTE  referance data - Copy (3).csv
#   inflating: folder/New1/LTE  referance data - Copy (4).csv
#   inflating: folder/New1/LTE  referance data - Copy (5).csv
#   inflating: folder/New1/LTE  referance data - Copy (6).csv
#   inflating: folder/New1/LTE  referance data - Copy (7).csv
#   inflating: folder/New1/LTE  referance data - Copy (8).csv
#   inflating: folder/New1/LTE  referance data - Copy (9).csv
#    creating: folder/New2/
#   inflating: folder/New2/LTE  referance data - Copy (17).csv
#   inflating: folder/New2/LTE  referance data - Copy (18).csv
#   inflating: folder/New2/LTE  referance data - Copy (19).csv
#   inflating: folder/New2/LTE  referance data - Copy (20).csv
#   inflating: folder/New2/LTE  referance data - Copy (21).csv
#   inflating: folder/New2/LTE  referance data - Copy (22).csv
#   inflating: folder/New2/LTE  referance data - Copy (23).csv
#   inflating: folder/New2/LTE  referance data - Copy (24).csv
#   inflating: folder/New2/LTE  referance data - Copy (25).csv
#   inflating: folder/New2/LTE  referance data - Copy (26).csv
#   inflating: folder/New2/LTE  referance data - Copy (27).csv
#   inflating: folder/New2/LTE  referance data - Copy (28).csv
#   inflating: folder/New2/LTE  referance data - Copy (29).csv
#   inflating: folder/New2/LTE  referance data - Copy (30).csv
#   inflating: folder/New2/LTE  referance data - Copy (31).csv

# %%
orig_dir="/content/folder/New1/"
all_data1 = pd.DataFrame()

for f in glob.glob("/content/folder/New1/*.csv"):
    df = pd.read_csv(f, encoding= 'unicode_escape')
    all_data1 = all_data1.append(df,ignore_index=True)
    print(f)
# Out:
# /content/folder/New1/LTE  referance data - Copy (1).csv
# /content/folder/New1/LTE  referance data - Copy (16).csv
# /content/folder/New1/LTE  referance data - Copy (3).csv
# /content/folder/New1/LTE  referance data - Copy (14).csv
# /content/folder/New1/LTE  referance data - Copy (10).csv
# /content/folder/New1/LTE  referance data - Copy (2).csv
# /content/folder/New1/LTE  referance data - Copy (11).csv
# /content/folder/New1/LTE  referance data - Copy (15).csv
# /content/folder/New1/LTE  referance data - Copy (8).csv
# /content/folder/New1/LTE  referance data - Copy (6).csv
# /content/folder/New1/LTE  referance data - Copy (7).csv
# /content/folder/New1/LTE  referance data - Copy (12).csv
# /content/folder/New1/LTE  referance data - Copy (9).csv
# /content/folder/New1/LTE  referance data - Copy (4).csv
# /content/folder/New1/LTE  referance data - Copy (13).csv
# /content/folder/New1/LTE  referance data - Copy (5).csv

# %%
orig_dir="/content/folder/New1/"
all_data2 = pd.DataFrame()

for f in glob.glob("/content/folder/New1/*.csv"):
    df = pd.read_csv(f, encoding= 'unicode_escape')
    all_data2 = all_data2.append(df,ignore_index=True)
    print(f)
# Out:
# /content/folder/New1/LTE  referance data - Copy (1).csv
# /content/folder/New1/LTE  referance data - Copy (16).csv
# /content/folder/New1/LTE  referance data - Copy (3).csv
# /content/folder/New1/LTE  referance data - Copy (14).csv
# /content/folder/New1/LTE  referance data - Copy (10).csv
# /content/folder/New1/LTE  referance data - Copy (2).csv
# /content/folder/New1/LTE  referance data - Copy (11).csv
# /content/folder/New1/LTE  referance data - Copy (15).csv
# /content/folder/New1/LTE  referance data - Copy (8).csv
# /content/folder/New1/LTE  referance data - Copy (6).csv
# /content/folder/New1/LTE  referance data - Copy (7).csv
# /content/folder/New1/LTE  referance data - Copy (12).csv
# /content/folder/New1/LTE  referance data - Copy (9).csv
# /content/folder/New1/LTE  referance data - Copy (4).csv
# /content/folder/New1/LTE  referance data - Copy (13).csv
# /content/folder/New1/LTE  referance data - Copy (5).csv

# %%
all_data1
# Out:
#                          cellid                cell_name     siteid celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594267  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594268  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594269  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594270  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594271  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594267  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594268     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594269         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594270         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594271         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ...    dateid outage_downtime planned_outage_downtime  \
# 0                NaN  ...  1/1/2023             NaN                     NaN
# 1                NaN  ...  1/1/2023             NaN                     NaN
# 2                NaN  ...  1/1/2023             NaN                     NaN
# 3                NaN  ...  1/1/2023             NaN                     NaN
# 4                NaN  ...  1/1/2023             NaN                     NaN
# ...              ...  ...       ...             ...                     ...
# 594267           NaN  ...  1/5/2023             NaN                     NaN
# 594268  Gesr El Suiz  ...  1/5/2023             NaN                     NaN
# 594269  Gesr El Suiz  ...  1/5/2023          1740.0                     NaN
# 594270       Tagamo3  ...  1/5/2023             NaN                     NaN
# 594271       Tagamo3  ...  1/5/2023             NaN                     NaN
#
#        uptime  downtime  totaltime  available_tchs  unavailable_tchs  \
# 0         NaN       NaN        NaN             NaN               NaN
# 1         NaN       NaN        NaN             NaN               NaN
# 2         NaN       NaN        NaN             NaN               NaN
# 3         NaN       NaN        NaN             NaN               NaN
# 4         NaN       NaN        NaN             NaN               NaN
# ...       ...       ...        ...             ...               ...
# 594267    NaN       NaN        NaN             NaN               NaN
# 594268    NaN       NaN        NaN             NaN               NaN
# 594269    NaN       NaN        NaN             NaN               NaN
# 594270    NaN       NaN        NaN             NaN               NaN
# 594271    NaN       NaN        NaN             NaN               NaN
#
#         configured_tchs  planned_outage_tch_loss
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
# ...                 ...                      ...
# 594267              NaN                      NaN
# 594268              NaN                      NaN
# 594269              NaN                      NaN
# 594270              NaN                      NaN
# 594271              NaN                      NaN
#
# [594272 rows x 23 columns]

# %%
all_data2
# Out:
#                          cellid                cell_name     siteid celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594267  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594268  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594269  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594270  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594271  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594267  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594268     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594269         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594270         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594271         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ...    dateid outage_downtime planned_outage_downtime  \
# 0                NaN  ...  1/1/2023             NaN                     NaN
# 1                NaN  ...  1/1/2023             NaN                     NaN
# 2                NaN  ...  1/1/2023             NaN                     NaN
# 3                NaN  ...  1/1/2023             NaN                     NaN
# 4                NaN  ...  1/1/2023             NaN                     NaN
# ...              ...  ...       ...             ...                     ...
# 594267           NaN  ...  1/5/2023             NaN                     NaN
# 594268  Gesr El Suiz  ...  1/5/2023             NaN                     NaN
# 594269  Gesr El Suiz  ...  1/5/2023          1740.0                     NaN
# 594270       Tagamo3  ...  1/5/2023             NaN                     NaN
# 594271       Tagamo3  ...  1/5/2023             NaN                     NaN
#
#        uptime  downtime  totaltime  available_tchs  unavailable_tchs  \
# 0         NaN       NaN        NaN             NaN               NaN
# 1         NaN       NaN        NaN             NaN               NaN
# 2         NaN       NaN        NaN             NaN               NaN
# 3         NaN       NaN        NaN             NaN               NaN
# 4         NaN       NaN        NaN             NaN               NaN
# ...       ...       ...        ...             ...               ...
# 594267    NaN       NaN        NaN             NaN               NaN
# 594268    NaN       NaN        NaN             NaN               NaN
# 594269    NaN       NaN        NaN             NaN               NaN
# 594270    NaN       NaN        NaN             NaN               NaN
# 594271    NaN       NaN        NaN             NaN               NaN
#
#         configured_tchs  planned_outage_tch_loss
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
# ...                 ...                      ...
# 594267              NaN                      NaN
# 594268              NaN                      NaN
# 594269              NaN                      NaN
# 594270              NaN                      NaN
# 594271              NaN                      NaN
#
# [594272 rows x 23 columns]

# %%
#all_data=all_data2
#all_data['Date'] = pd.to_datetime(all_data['dateid'], errors='coerce')
#count = all_data.groupby(all_data['Date'].dt.date).size()
#count

# %%
all_data1.to_csv('/content/drive/MyDrive/lte/out1.csv', index=False)

# %%
all_data2.to_csv('/content/drive/MyDrive/lte/out2.csv', index=False)

# %%
referance_data = pd.read_csv('/content/drive/MyDrive/lte/out2.csv', parse_dates=['dateid'])

# %%
referance_data
# Out:
#                          cellid                cell_name     siteid celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594267  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594268  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594269  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594270  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594271  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594267  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594268     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594269         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594270         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594271         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ...     dateid outage_downtime planned_outage_downtime  \
# 0                NaN  ... 2023-01-01             NaN                     NaN
# 1                NaN  ... 2023-01-01             NaN                     NaN
# 2                NaN  ... 2023-01-01             NaN                     NaN
# 3                NaN  ... 2023-01-01             NaN                     NaN
# 4                NaN  ... 2023-01-01             NaN                     NaN
# ...              ...  ...        ...             ...                     ...
# 594267           NaN  ... 2023-01-05             NaN                     NaN
# 594268  Gesr El Suiz  ... 2023-01-05             NaN                     NaN
# 594269  Gesr El Suiz  ... 2023-01-05          1740.0                     NaN
# 594270       Tagamo3  ... 2023-01-05             NaN                     NaN
# 594271       Tagamo3  ... 2023-01-05             NaN                     NaN
#
#        uptime  downtime  totaltime  available_tchs  unavailable_tchs  \
# 0         NaN       NaN        NaN             NaN               NaN
# 1         NaN       NaN        NaN             NaN               NaN
# 2         NaN       NaN        NaN             NaN               NaN
# 3         NaN       NaN        NaN             NaN               NaN
# 4         NaN       NaN        NaN             NaN               NaN
# ...       ...       ...        ...             ...               ...
# 594267    NaN       NaN        NaN             NaN               NaN
# 594268    NaN       NaN        NaN             NaN               NaN
# 594269    NaN       NaN        NaN             NaN               NaN
# 594270    NaN       NaN        NaN             NaN               NaN
# 594271    NaN       NaN        NaN             NaN               NaN
#
#         configured_tchs  planned_outage_tch_loss
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
# ...                 ...                      ...
# 594267              NaN                      NaN
# 594268              NaN                      NaN
# 594269              NaN                      NaN
# 594270              NaN                      NaN
# 594271              NaN                      NaN
#
# [594272 rows x 23 columns]

# %%
referance_data.columns
# Out:
# Index(['cellid', 'cell_name', 'siteid', 'celltype', 'controller', 'vendor',
#        'cell_status', 'site_status', 'site_subcategory', 'area', 'zone',
#        'tier', 'mrcorp', 'dateid', 'outage_downtime',
#        'planned_outage_downtime', 'uptime', 'downtime', 'totaltime',
#        'available_tchs', 'unavailable_tchs', 'configured_tchs',
#        'planned_outage_tch_loss'],
#       dtype='object')

# %%
myDataFrame.columns
# Out:
# Index(['dateid', 'cellid', 'siteid', 'Down Time - M'], dtype='object')

# %%
s = 'dateid' == 'dateid'
s
# Out:
# True

# %%
d='cellid'=='cellid'
d
# Out:
# True

# %%
myDataFrame
# Out:
#            dateid                   cellid    siteid  Down Time - M
# 0      2023-01-01  LCAI1235_12352_N_Z_D3-2  LCAI1235            0.0
# 1      2023-01-01  LCAI1235_12354_N_Z_D3-4  LCAI1235            0.0
# 2      2023-01-01  LCAI1235_12353_N_Z_D3-3  LCAI1235            0.0
# 3      2023-01-01  LCAI1235_12351_N_Z_D3-1  LCAI1235            0.0
# 4      2023-01-01  LCAI1639_16392_N_Z_D3-2  LCAI1639          900.0
# ...           ...                      ...       ...            ...
# 599149 2023-01-01  LCAI6072_60724_N_E_D3-4  MCAI6072            NaN
# 599150 2023-01-01  LCAI6072_60725_N_E_G1-1  MCAI6072            NaN
# 599151 2023-01-01  LCAI6072_60726_N_E_G1-2  MCAI6072            NaN
# 599152 2023-01-01  LCAI6072_60727_N_E_G1-3  MCAI6072            NaN
# 599153 2023-01-01  LCAI6072_60728_N_E_G1-4  MCAI6072            NaN
#
# [1076150 rows x 4 columns]

# %%
result = pd.merge(referance_data, myDataFrame, how="left", on=['dateid','cellid'])
result
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594701  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594702  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594703  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594704  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594705  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594701  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594702     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594703         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594704         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594705         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... planned_outage_downtime uptime downtime totaltime  \
# 0                NaN  ...                     NaN    NaN      NaN       NaN
# 1                NaN  ...                     NaN    NaN      NaN       NaN
# 2                NaN  ...                     NaN    NaN      NaN       NaN
# 3                NaN  ...                     NaN    NaN      NaN       NaN
# 4                NaN  ...                     NaN    NaN      NaN       NaN
# ...              ...  ...                     ...    ...      ...       ...
# 594701           NaN  ...                     NaN    NaN      NaN       NaN
# 594702  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594703  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594704       Tagamo3  ...                     NaN    NaN      NaN       NaN
# 594705       Tagamo3  ...                     NaN    NaN      NaN       NaN
#
#         available_tchs  unavailable_tchs  configured_tchs  \
# 0                  NaN               NaN              NaN
# 1                  NaN               NaN              NaN
# 2                  NaN               NaN              NaN
# 3                  NaN               NaN              NaN
# 4                  NaN               NaN              NaN
# ...                ...               ...              ...
# 594701             NaN               NaN              NaN
# 594702             NaN               NaN              NaN
# 594703             NaN               NaN              NaN
# 594704             NaN               NaN              NaN
# 594705             NaN               NaN              NaN
#
#         planned_outage_tch_loss  siteid_y  Down Time - M
# 0                           NaN       NaN            NaN
# 1                           NaN       NaN            NaN
# 2                           NaN       NaN            NaN
# 3                           NaN       NaN            NaN
# 4                           NaN       NaN            NaN
# ...                         ...       ...            ...
# 594701                      NaN       NaN            NaN
# 594702                      NaN  LCAI2490            0.0
# 594703                      NaN  MCAI0650            0.0
# 594704                      NaN  MCAI5260            0.0
# 594705                      NaN  LCAI5298            0.0
#
# [594706 rows x 25 columns]

# %%
result.describe()
# Out:
#        outage_downtime  planned_outage_downtime  uptime  downtime  totaltime  \
# count     37632.000000               800.000000     0.0       0.0        0.0
# mean       3617.015306              1848.000000     NaN       NaN        NaN
# std        7752.078572              1477.069791     NaN       NaN        NaN
# min           0.000000               420.000000     NaN       NaN        NaN
# 25%         120.000000               420.000000     NaN       NaN        NaN
# 50%         780.000000              1320.000000     NaN       NaN        NaN
# 75%        3780.000000              3060.000000     NaN       NaN        NaN
# max       60480.000000              4740.000000     NaN       NaN        NaN
#
#        available_tchs  unavailable_tchs  configured_tchs  \
# count             0.0               0.0              0.0
# mean              NaN               NaN              NaN
# std               NaN               NaN              NaN
# min               NaN               NaN              NaN
# 25%               NaN               NaN              NaN
# 50%               NaN               NaN              NaN
# 75%               NaN               NaN              NaN
# max               NaN               NaN              NaN
#
#        planned_outage_tch_loss  Down Time - M
# count                      0.0  346640.000000
# mean                       NaN     429.785371
# std                        NaN    4440.643154
# min                        NaN       0.000000
# 25%                        NaN       0.000000
# 50%                        NaN       0.000000
# 75%                        NaN       0.000000
# max                        NaN   86400.000000

# %%
result.to_csv('/content/drive/MyDrive/lte/dataframeout2.csv', index=False)

# %%
# !sudo pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.8-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 3.9 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.8

# %%
writer = pd.ExcelWriter("dataframe.xlsx", engine='xlsxwriter')
result.to_excel(writer,sheet_name = 'sheet1', index=False)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-65b3333b1167> in <module>
#       1 writer = pd.ExcelWriter("dataframe.xlsx", engine='xlsxwriter')
# ----> 2 result.to_excel(writer,sheet_name = 'sheet1', index=False)
#       3 writer.save()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     821         num_rows, num_cols = self.df.shape
#     822         if num_rows > self.max_rows or num_cols > self.max_cols:
# --> 823             raise ValueError(
#     824                 f"This sheet is too large! Your sheet size is: {num_rows}, {num_cols} "
#     825                 f"Max sheet size is: {self.max_rows}, {self.max_cols}"
#
# ValueError: This sheet is too large! Your sheet size is: 1151402, 27 Max sheet size is: 1048576, 16384

# %%
ava_data = pd.read_csv('/content/drive/MyDrive/lte/dataframeout2.csv', parse_dates=['dateid'])

# %%
ava_data
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594701  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594702  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594703  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594704  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594705  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594701  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594702     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594703         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594704         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594705         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... planned_outage_downtime uptime downtime totaltime  \
# 0                NaN  ...                     NaN    NaN      NaN       NaN
# 1                NaN  ...                     NaN    NaN      NaN       NaN
# 2                NaN  ...                     NaN    NaN      NaN       NaN
# 3                NaN  ...                     NaN    NaN      NaN       NaN
# 4                NaN  ...                     NaN    NaN      NaN       NaN
# ...              ...  ...                     ...    ...      ...       ...
# 594701           NaN  ...                     NaN    NaN      NaN       NaN
# 594702  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594703  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594704       Tagamo3  ...                     NaN    NaN      NaN       NaN
# 594705       Tagamo3  ...                     NaN    NaN      NaN       NaN
#
#         available_tchs  unavailable_tchs  configured_tchs  \
# 0                  NaN               NaN              NaN
# 1                  NaN               NaN              NaN
# 2                  NaN               NaN              NaN
# 3                  NaN               NaN              NaN
# 4                  NaN               NaN              NaN
# ...                ...               ...              ...
# 594701             NaN               NaN              NaN
# 594702             NaN               NaN              NaN
# 594703             NaN               NaN              NaN
# 594704             NaN               NaN              NaN
# 594705             NaN               NaN              NaN
#
#         planned_outage_tch_loss  siteid_y  Down Time - M
# 0                           NaN       NaN            NaN
# 1                           NaN       NaN            NaN
# 2                           NaN       NaN            NaN
# 3                           NaN       NaN            NaN
# 4                           NaN       NaN            NaN
# ...                         ...       ...            ...
# 594701                      NaN       NaN            NaN
# 594702                      NaN  LCAI2490            0.0
# 594703                      NaN  MCAI0650            0.0
# 594704                      NaN  MCAI5260            0.0
# 594705                      NaN  LCAI5298            0.0
#
# [594706 rows x 25 columns]

# %%
ava_data['Down Time - M'] = ava_data['Down Time - M'].div(60)

# %%
ava_data['Down Time - M'].max()
# Out:
# 1440.0

# %%
ava_data
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 594701  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 594702  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 594703  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 594704  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 594705  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 594701  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 594702     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 594703         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594704         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 594705         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... planned_outage_downtime uptime downtime totaltime  \
# 0                NaN  ...                     NaN    NaN      NaN       NaN
# 1                NaN  ...                     NaN    NaN      NaN       NaN
# 2                NaN  ...                     NaN    NaN      NaN       NaN
# 3                NaN  ...                     NaN    NaN      NaN       NaN
# 4                NaN  ...                     NaN    NaN      NaN       NaN
# ...              ...  ...                     ...    ...      ...       ...
# 594701           NaN  ...                     NaN    NaN      NaN       NaN
# 594702  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594703  Gesr El Suiz  ...                     NaN    NaN      NaN       NaN
# 594704       Tagamo3  ...                     NaN    NaN      NaN       NaN
# 594705       Tagamo3  ...                     NaN    NaN      NaN       NaN
#
#         available_tchs  unavailable_tchs  configured_tchs  \
# 0                  NaN               NaN              NaN
# 1                  NaN               NaN              NaN
# 2                  NaN               NaN              NaN
# 3                  NaN               NaN              NaN
# 4                  NaN               NaN              NaN
# ...                ...               ...              ...
# 594701             NaN               NaN              NaN
# 594702             NaN               NaN              NaN
# 594703             NaN               NaN              NaN
# 594704             NaN               NaN              NaN
# 594705             NaN               NaN              NaN
#
#         planned_outage_tch_loss  siteid_y  Down Time - M
# 0                           NaN       NaN            NaN
# 1                           NaN       NaN            NaN
# 2                           NaN       NaN            NaN
# 3                           NaN       NaN            NaN
# 4                           NaN       NaN            NaN
# ...                         ...       ...            ...
# 594701                      NaN       NaN            NaN
# 594702                      NaN  LCAI2490            0.0
# 594703                      NaN  MCAI0650            0.0
# 594704                      NaN  MCAI5260            0.0
# 594705                      NaN  LCAI5298            0.0
#
# [594706 rows x 25 columns]

# %%
ava_data['id']=ava_data['siteid_x'].str[-7:]

# %%
outage = pd.read_excel('/content/drive/MyDrive/lte/AccumulatedOutage.xlsx')
outage
# Out:
#            siteid     site                                              cells  \
# 0        UDEL4561  DEL4561   UDEL45611 UDEL45613 UDEL45614 UDEL45616 UDEL4...
# 1         DEL4561  DEL4561    45611 45612 45613 45614 45616 45617 45618 45619
# 2         CAI2443  CAI2443                                  2443A 2443B 2443C
# 3        UCAI2227  CAI2227   UCAI22271 UCAI22272 UCAI22273 UCAI22274 UCAI2...
# 4       HUCAI6037  CAI6037                                    HU60371 HU60375
# ...           ...      ...                                                ...
# 142019   UCAI3026  CAI3026                                UCAI30261 UCAI30265
# 142020   UCAI3026  CAI3026                                UCAI30261 UCAI30265
# 142021   UCAI3026  CAI3026                                UCAI30261 UCAI30265
# 142022   UCAI3026  CAI3026                                UCAI30261 UCAI30265
# 142023   UCAI3026  CAI3026                                                NaN
#
#         cellcount controller rbstype          area  number_of_cascaded   tier  \
# 0             9.0      TRZ11   Macro         Delta                 1.0  Tier4
# 1             8.0      TBZ10   Macro         Delta                 1.0  Tier4
# 2             3.0      CBX36   Macro       Tagamo3                 0.0  Tier3
# 3            12.0      KRX08   Macro  Gesr El Suiz                 3.0  Tier1
# 4             2.0      YRH35   Micro        Helwan                 0.0  Tier3
# ...           ...        ...     ...           ...                 ...    ...
# 142019        2.0      VRX09   Micro       Tagamo3                 0.0  Tier1
# 142020        2.0      VRX09   Micro       Tagamo3                 0.0  Tier1
# 142021        2.0      VRX09   Micro       Tagamo3                 0.0  Tier1
# 142022        2.0      VRX09   Micro       Tagamo3                 0.0  Tier1
# 142023        0.0      VRX09   Micro       Tagamo3                 0.0  Tier1
#
#                  eventtime  ... dependency_reason   notcascaded  zone_1_2  \
# 0      2023-02-10 23:59:29  ...               NaN  Not Cascaded     Zone2
# 1      2023-02-10 23:59:06  ...               NaN  Not Cascaded     Zone2
# 2      2023-02-10 23:55:39  ...               NaN  Not Cascaded     Zone1
# 3      2023-02-10 23:54:50  ...               NaN  Not Cascaded     Zone2
# 4      2023-02-10 23:50:05  ...               NaN  Not Cascaded     Zone1
# ...                    ...  ...               ...           ...       ...
# 142019 2022-09-16 03:02:53  ...               NaN  Not Cascaded     Zone1
# 142020 2022-09-16 03:02:53  ...               NaN  Not Cascaded     Zone1
# 142021 2022-09-16 03:02:53  ...               NaN  Not Cascaded     Zone1
# 142022 2022-09-16 03:02:53  ...               NaN  Not Cascaded     Zone1
# 142023 2022-09-16 03:02:53  ...               NaN  Not Cascaded     Zone1
#
#         celltype majorproblem      sub_majorproblem site_with_cascaded  \
# 0             3G        Power      Power_Commercial            DEL4561
# 1             2G        Power      Power_Commercial            DEL4561
# 2             2G        Power      Power_Commercial            CAI2443
# 3             3G        Other  Other_Unknown_Reason            CAI2227
# 4             3G        Other  Other_Unknown_Reason            CAI6037
# ...          ...          ...                   ...                ...
# 142019        3G    High_Temp             High_Temp            CAI3026
# 142020        3G    High_Temp             High_Temp            CAI3026
# 142021        3G    High_Temp             High_Temp            CAI3026
# 142022        3G    High_Temp             High_Temp            CAI3026
# 142023        3G    High_Temp             High_Temp            CAI3026
#
#              MR_CP Week Mounth
# 0              NaN    6      2
# 1              NaN    6      2
# 2       Major Road    6      2
# 3       Major Road    6      2
# 4       Major Road    6      2
# ...            ...  ...    ...
# 142019         NaN    3      1
# 142020         NaN    3      1
# 142021         NaN    3      1
# 142022         NaN    3      1
# 142023         NaN    3      1
#
# [142024 rows x 57 columns]

# %%
outage = pd.read_excel('/content/drive/MyDrive/lte/AccumulatedOutage.xlsx',usecols=[0,1,11,39,50], names=['siteid', 'id', 'outage-Down Time - M', 'dateid', 'ServiceType'], parse_dates=['dateid'])
outage
# Out:
#            siteid       id  outage-Down Time - M     dateid ServiceType
# 0        UDEL4561  DEL4561                   0.0 2023-02-10          3G
# 1         DEL4561  DEL4561                   0.0 2023-02-10          2G
# 2         CAI2443  CAI2443                   4.0 2023-02-10          2G
# 3        UCAI2227  CAI2227                   5.0 2023-02-10          3G
# 4       HUCAI6037  CAI6037                   0.0 2023-02-10          3G
# ...           ...      ...                   ...        ...         ...
# 142019   UCAI3026  CAI3026                1440.0 2023-01-15          3G
# 142020   UCAI3026  CAI3026                1440.0 2023-01-16          3G
# 142021   UCAI3026  CAI3026                1440.0 2023-01-17          3G
# 142022   UCAI3026  CAI3026                1440.0 2023-01-18          3G
# 142023   UCAI3026  CAI3026                1063.0 2023-01-19          3G
#
# [142024 rows x 5 columns]

# %%
outage
# Out:
#         siteid_y       id  outage-Down Time - M     dateid ServiceType
# 0       UCAI5371  CAI5371                 227.0 2023-01-08          3G
# 1       UCAI5014  CAI5014                 227.0 2023-01-08          3G
# 2        CAI5371  CAI5371                 226.0 2023-01-08          2G
# 3       UCAI5560  CAI5560                 227.0 2023-01-08          3G
# 4       LCAI5560  CAI5560                 228.0 2023-01-08         LTE
# ...          ...      ...                   ...        ...         ...
# 124580  UCAI0985  CAI0985                   0.0 2023-02-03          3G
# 124581  UCAI0325  CAI0325                   0.0 2023-02-03          3G
# 124582  UCAI1872  CAI1872                   0.0 2023-02-03          3G
# 124583  UCAI2479  CAI2479                   0.0 2023-02-03          3G
# 124584  UCAI5061  CAI5061                   0.0 2023-02-03          3G
#
# [124585 rows x 5 columns]

# %%
outage = outage[outage['ServiceType'] == 'LTE']

# %%
outage.describe()
# Out:
#        outage-Down Time - M
# count          34269.000000
# mean              35.584843
# std              118.486004
# min                0.000000
# 25%                1.000000
# 50%                4.000000
# 75%               17.000000
# max             1440.000000

# %%
outage['ServiceType'].describe(include="all")
# Out:
# count     34269
# unique        1
# top         LTE
# freq      34269
# Name: ServiceType, dtype: object

# %%
outage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34269 entries, 6 to 141907
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   siteid                34269 non-null  object
#  1   id                    34269 non-null  object
#  2   outage-Down Time - M  34269 non-null  float64
#  3   dateid                34269 non-null  datetime64[ns]
#  4   ServiceType           34269 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 1.6+ MB

# %%
result = pd.merge(ava_data, outage, how="left", on=['dateid','id'])
result
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 675727  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 675728  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 675729  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 675730  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 675731  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 675727  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 675728     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 675729         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675730         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675731         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... available_tchs unavailable_tchs configured_tchs  \
# 0                NaN  ...            NaN              NaN             NaN
# 1                NaN  ...            NaN              NaN             NaN
# 2                NaN  ...            NaN              NaN             NaN
# 3                NaN  ...            NaN              NaN             NaN
# 4                NaN  ...            NaN              NaN             NaN
# ...              ...  ...            ...              ...             ...
# 675727           NaN  ...            NaN              NaN             NaN
# 675728  Gesr El Suiz  ...            NaN              NaN             NaN
# 675729  Gesr El Suiz  ...            NaN              NaN             NaN
# 675730       Tagamo3  ...            NaN              NaN             NaN
# 675731       Tagamo3  ...            NaN              NaN             NaN
#
#        planned_outage_tch_loss  siteid_y  Down Time - M       id  siteid  \
# 0                          NaN       NaN            NaN  CAI1330     NaN
# 1                          NaN       NaN            NaN  CAI2157     NaN
# 2                          NaN       NaN            NaN  CAI1484     NaN
# 3                          NaN       NaN            NaN  CAI3512     NaN
# 4                          NaN       NaN            NaN  CAI0770     NaN
# ...                        ...       ...            ...      ...     ...
# 675727                     NaN       NaN            NaN  CAI1832     NaN
# 675728                     NaN  LCAI2490            0.0  CAI2490     NaN
# 675729                     NaN  MCAI0650            0.0  CAI0650     NaN
# 675730                     NaN  MCAI5260            0.0  CAI5260     NaN
# 675731                     NaN  LCAI5298            0.0  CAI5298     NaN
#
#         outage-Down Time - M  ServiceType
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# ...                      ...          ...
# 675727                   NaN          NaN
# 675728                   NaN          NaN
# 675729                   NaN          NaN
# 675730                   NaN          NaN
# 675731                   NaN          NaN
#
# [675732 rows x 29 columns]

# %%
result.describe()
# Out:
#        outage_downtime  planned_outage_downtime  uptime  downtime  totaltime  \
# count     43495.000000               886.000000     0.0       0.0        0.0
# mean       3465.768019              1941.805869     NaN       NaN        NaN
# std        7476.255230              1456.706722     NaN       NaN        NaN
# min           0.000000               420.000000     NaN       NaN        NaN
# 25%         180.000000               420.000000     NaN       NaN        NaN
# 50%         780.000000              1860.000000     NaN       NaN        NaN
# 75%        3720.000000              3060.000000     NaN       NaN        NaN
# max       60480.000000              4740.000000     NaN       NaN        NaN
#
#        available_tchs  unavailable_tchs  configured_tchs  \
# count             0.0               0.0              0.0
# mean              NaN               NaN              NaN
# std               NaN               NaN              NaN
# min               NaN               NaN              NaN
# 25%               NaN               NaN              NaN
# 50%               NaN               NaN              NaN
# 75%               NaN               NaN              NaN
# max               NaN               NaN              NaN
#
#        planned_outage_tch_loss  Down Time - M  outage-Down Time - M
# count                      0.0  381548.000000         131761.000000
# mean                       NaN      16.332909             30.460895
# std                        NaN      95.769985            110.295781
# min                        NaN       0.000000              0.000000
# 25%                        NaN       0.000000              1.000000
# 50%                        NaN       0.000000              3.000000
# 75%                        NaN       0.000000             11.000000
# max                        NaN    1440.000000           1440.000000

# %%
result['Total Down Time - M'] = result['Down Time - M'] + result['outage-Down Time - M']

# %%
result
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 675727  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 675728  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 675729  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 675730  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 675731  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 675727  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 675728     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 675729         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675730         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675731         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... unavailable_tchs configured_tchs  \
# 0                NaN  ...              NaN             NaN
# 1                NaN  ...              NaN             NaN
# 2                NaN  ...              NaN             NaN
# 3                NaN  ...              NaN             NaN
# 4                NaN  ...              NaN             NaN
# ...              ...  ...              ...             ...
# 675727           NaN  ...              NaN             NaN
# 675728  Gesr El Suiz  ...              NaN             NaN
# 675729  Gesr El Suiz  ...              NaN             NaN
# 675730       Tagamo3  ...              NaN             NaN
# 675731       Tagamo3  ...              NaN             NaN
#
#        planned_outage_tch_loss  siteid_y  Down Time - M       id  siteid  \
# 0                          NaN       NaN            NaN  CAI1330     NaN
# 1                          NaN       NaN            NaN  CAI2157     NaN
# 2                          NaN       NaN            NaN  CAI1484     NaN
# 3                          NaN       NaN            NaN  CAI3512     NaN
# 4                          NaN       NaN            NaN  CAI0770     NaN
# ...                        ...       ...            ...      ...     ...
# 675727                     NaN       NaN            NaN  CAI1832     NaN
# 675728                     NaN  LCAI2490            0.0  CAI2490     NaN
# 675729                     NaN  MCAI0650            0.0  CAI0650     NaN
# 675730                     NaN  MCAI5260            0.0  CAI5260     NaN
# 675731                     NaN  LCAI5298            0.0  CAI5298     NaN
#
#         outage-Down Time - M  ServiceType  Total Down Time - M
# 0                        NaN          NaN                  NaN
# 1                        NaN          NaN                  NaN
# 2                        NaN          NaN                  NaN
# 3                        NaN          NaN                  NaN
# 4                        NaN          NaN                  NaN
# ...                      ...          ...                  ...
# 675727                   NaN          NaN                  NaN
# 675728                   NaN          NaN                  NaN
# 675729                   NaN          NaN                  NaN
# 675730                   NaN          NaN                  NaN
# 675731                   NaN          NaN                  NaN
#
# [675732 rows x 30 columns]

# %%
result['Total Down Time - s'] = result['Total Down Time - M']*60

# %%
result
# Out:
#                          cellid                cell_name   siteid_x celltype  \
# 0       LCAI1330_13301_N_H_D3-1  LCAI1330_13301_N_H_D3-1   LCAI1330      LTE
# 1       LCAI2157_21570_X_H_D6-1  LCAI2157_21570_X_H_D6-1   LCAI2157      LTE
# 2       LCAI1484_14841_N_H_D3-1  LCAI1484_14841_N_H_D3-1   LCAI1484      LTE
# 3       LCAI3512_35123_N_H_D7-3  LCAI3512_35123_N_H_D7-3   LCAI3512      LTE
# 4       LCAI0770_07706_N_H_G1-1  LCAI0770_07706_N_H_G1-1  ULCAI0770      LTE
# ...                         ...                      ...        ...      ...
# 675727  LCAI1832_52094_N_H_T4-4  LCAI1832_52094_N_H_T4-4   LCAI1832      LTE
# 675728  LCAI2490_24908_N_Z_G1-4  LCAI2490_24908_N_Z_G1-4   LCAI2490      LTE
# 675729  LCAI0650_57515_N_E_T8-1  LCAI0650_57515_N_E_T8-1   LCAI0650      LTE
# 675730  LCAI5260_52607_N_E_G1-3  LCAI5260_52607_N_E_G1-3   LCAI5260      LTE
# 675731  LCAI5298_52981_I_E_D1-1  LCAI5298_52981_I_E_D1-1   LCAI5298      LTE
#
#         controller    vendor cell_status site_status site_subcategory  \
# 0       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 1       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 2       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 3       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 4       LTE_Huawei    Huawei      ON AIR         NaN              NaN
# ...            ...       ...         ...         ...              ...
# 675727  LTE_Huawei    Huawei      ON AIR         NaN              NaN
# 675728     LTE_ZTE       ZTE      ON AIR      ON AIR    FM Inspection
# 675729         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675730         LTE  Ericsson      ON AIR      ON AIR    FM Inspection
# 675731         LTE  Ericsson      ON AIR      ON AIR              EOT
#
#                 area  ... configured_tchs planned_outage_tch_loss  siteid_y  \
# 0                NaN  ...             NaN                     NaN       NaN
# 1                NaN  ...             NaN                     NaN       NaN
# 2                NaN  ...             NaN                     NaN       NaN
# 3                NaN  ...             NaN                     NaN       NaN
# 4                NaN  ...             NaN                     NaN       NaN
# ...              ...  ...             ...                     ...       ...
# 675727           NaN  ...             NaN                     NaN       NaN
# 675728  Gesr El Suiz  ...             NaN                     NaN  LCAI2490
# 675729  Gesr El Suiz  ...             NaN                     NaN  MCAI0650
# 675730       Tagamo3  ...             NaN                     NaN  MCAI5260
# 675731       Tagamo3  ...             NaN                     NaN  LCAI5298
#
#        Down Time - M       id  siteid  outage-Down Time - M  ServiceType  \
# 0                NaN  CAI1330     NaN                   NaN          NaN
# 1                NaN  CAI2157     NaN                   NaN          NaN
# 2                NaN  CAI1484     NaN                   NaN          NaN
# 3                NaN  CAI3512     NaN                   NaN          NaN
# 4                NaN  CAI0770     NaN                   NaN          NaN
# ...              ...      ...     ...                   ...          ...
# 675727           NaN  CAI1832     NaN                   NaN          NaN
# 675728           0.0  CAI2490     NaN                   NaN          NaN
# 675729           0.0  CAI0650     NaN                   NaN          NaN
# 675730           0.0  CAI5260     NaN                   NaN          NaN
# 675731           0.0  CAI5298     NaN                   NaN          NaN
#
#         Total Down Time - M  Total Down Time - s
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
# ...                     ...                  ...
# 675727                  NaN                  NaN
# 675728                  NaN                  NaN
# 675729                  NaN                  NaN
# 675730                  NaN                  NaN
# 675731                  NaN                  NaN
#
# [675732 rows x 31 columns]

# %%
result.to_csv('/content/drive/MyDrive/lte/FinalDataFrameout2.csv', index=False)

# %%
# !zip -r '/content/drive/MyDrive/lte/FinalDataFrameout1.zip' '/content/drive/MyDrive/lte/FinalDataFrameout1.csv'
# Out:
#   adding: content/drive/MyDrive/lte/FinalDataFrameout1.csv (deflated 88%)
